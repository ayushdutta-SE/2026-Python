# %% [markdown]
# ## Hello World

# %%
print("Ayush Dutta")
# Out:
# Ayush Dutta

# %%
name=input('What is your name? ')
colour=input('What is your fav colour? ')
print(name+' likes '+colour)
# Out:
# Ayush Dutta likes RED

# %%
weight=input("What is your weight(in pounds): ")
weight_kg=int(weight)*0.45
print(weight_kg)
# Out:
# 65.25

# %%
import math

print(math.ceil(-2.9))
# Out:
# -2

# %%
price_of_house=1000000

credit=False

if credit:
  print(price_of_house*0.10)
else:
 downpayment= price_of_house*0.20
 print(f"Down Payment={downpayment}")
print('Hello')
# Out:
# Down Payment=200000.0
# Hello

# %%
prices=[10,20,30]
total_price=0
for item in prices:
  total_price=item+total_price
print(total_price)
# Out:
# 60

# %%
for item in range(11):
  print(item)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 for item in 11:
#       2   print(item)
#
# TypeError: 'int' object is not iterable

# %%
numbers=[5,2,5,2,2]
for x_count in numbers:
  output=''
  for count in range(x_count):
    output+='x'
  print(output)
# Out:
# xxxxx
# xx
# xxxxx
# xx
# xx

# %%
name="a"

if len(name)<3:
  print('Name should be more than 3 characters')
elif len(name)>50:
  print('name should be less than 50 character')
else:
  print('Perfect name')
# Out:
# Name should be more than 3 characters
