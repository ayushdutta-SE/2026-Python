# %% [markdown]
# ### Reverse a list without using the built-in reverse() function.

# %%
number=[30,49,60,46,88]

new_number=number[::-1]
#print(len(number))
# for item in range(len(number)-1,0,-1):
#   print(number[item])
print(new_number)
#print(number[4])
# Out:
# [88, 46, 60, 49, 30]

# %%
mytuple = ("apple", "banana", "cherry")

temp = list(mytuple)

temp.append("mango")

mytuple = tuple(temp)

print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'mango')

# %%
number=[30,49,60,46,88]
